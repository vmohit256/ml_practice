# %% [markdown]
# This notebook assigns each titles to a unique region of origin.

# %%
import importlib
import src.imdb_views as imdb_views
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

_ = importlib.reload(imdb_views)

# %%
reader = imdb_views.IMDBDataReader("../../PublicDatasets/IMDB/")

# %%
ratings = reader.get_ratings()
title_basics = reader.get_title_basics()

# take intersection of titles with ratings and basic information to reduce the size of the dataset
titles_with_ratings_and_basic_info = \
    ratings[['tconst']].drop_duplicates()\
    .merge(title_basics[['tconst']].drop_duplicates(), on='tconst', how='inner')
ratings = ratings.merge(titles_with_ratings_and_basic_info, on='tconst', how='inner')
title_basics = title_basics.merge(titles_with_ratings_and_basic_info, on='tconst', how='inner')

title_regions = reader.get_title_regions(titles_to_fetch=titles_with_ratings_and_basic_info)

# keep only titles with regions
titles_w_ratings_basic_info_and_regions = \
    titles_with_ratings_and_basic_info\
    .merge(title_regions[['tconst']].drop_duplicates(), on='tconst', how='inner')

ratings = ratings.merge(titles_w_ratings_basic_info_and_regions, on='tconst', how='inner')
title_basics = title_basics.merge(titles_w_ratings_basic_info_and_regions, on='tconst', how='inner')
title_regions = title_regions.merge(titles_w_ratings_basic_info_and_regions, on='tconst', how='inner')

title_to_names = reader.get_title_to_names(titles_to_fetch=titles_w_ratings_basic_info_and_regions)
# Out:
# Time taken to read ratings data: 0.6358175277709961 seconds
# Time taken to read title basics data: 17.683849334716797 seconds
# Time taken to read title regions data: 66.46048855781555 seconds
# Time taken to compute the final title to names dataframe: 1.8792967875798543 mins

# %%
# naive method: assign each name to region of origin by picking
# the region containing most votes for that name
# then assign each title to region of origin by picking
# region containing most votes for the names of the title

# %%
name_to_region_of_origin = title_to_names\
    .merge(title_basics[['tconst', 'titleType']], on='tconst')\
    .merge(ratings[['tconst', 'numVotes']], on='tconst', how='inner')\
    .merge(title_regions.query('language == "ALL"')[['tconst', 'region']], on='tconst', how='inner')\
    .groupby(['titleType', 'primaryName', 'region'])\
    .agg({'numVotes': 'sum', 'tconst': 'count'})\
    .reset_index()\
    .rename(columns={'tconst': 'numTitles'})
    
name_to_region_of_origin['RegionRankPerName'] = \
    name_to_region_of_origin.groupby(['titleType', 'primaryName'])['numVotes'].rank(method='dense', ascending=False)

name_to_region_of_origin['TotalNumVotes'] = \
    name_to_region_of_origin.groupby(['titleType', 'primaryName'])['numVotes'].transform('sum')

name_to_region_of_origin = name_to_region_of_origin.query('RegionRankPerName == 1')

# %%
# what fraction of names have inconclusive region of origin at this point?
# i.e., they have more than 1 regions tied in terms of number of votes

name_to_num_regions_of_origin = name_to_region_of_origin\
    .groupby(['titleType', 'primaryName'])\
    .agg({'region': 'count', 'TotalNumVotes': 'sum'})\
    .reset_index()\
    .rename(columns={'region': 'numRegionsOfOrigin'})

stats = name_to_num_regions_of_origin\
    .groupby(['titleType', 'numRegionsOfOrigin'])\
    .agg({'primaryName': 'count', 'TotalNumVotes': 'sum'})\
    .reset_index()\
    .rename(columns={'primaryName': 'numNames'})

stats['PercentageByCount'] = 100 * stats['numNames'] / stats.groupby('titleType')['numNames'].transform('sum')
stats['PercentageByVotes'] = 100 * stats['TotalNumVotes'] / stats.groupby('titleType')['TotalNumVotes'].transform('sum')

stats
# Out:
#    titleType  numRegionsOfOrigin  numNames  TotalNumVotes  PercentageByCount  \
# 0      movie                   1    357416    46863805902          50.623488
# 1      movie                   2    173198    29245120016          24.531322
# 2      movie                   3     69014    12145261785           9.774966
# 3      movie                   4     40198    12129870564           5.693542
# 4      movie                   5     27111    11094158140           3.839933
# 5      movie                   6     20379    15910553616           2.886429
# 6      movie                   7     18712    48912021333           2.650320
# 7   tvSeries                   1    126200     4891346274          64.681793
# 8   tvSeries                   2     28876     1199751788          14.799932
# 9   tvSeries                   3     12775     1300489344           6.547622
# 10  tvSeries                   4      7230     1248125748           3.705621
# 11  tvSeries                   5      5499     1464126750           2.818425
# 12  tvSeries                   6      5060     2721279270           2.593422
# 13  tvSeries                   7      9469    14635767811           4.853185
#
#     PercentageByVotes
# 0           26.581733
# 1           16.588196
# 2            6.888943
# 3            6.880213
# 4            6.292744
# 5            9.024664
# 6           27.743506
# 7           17.812048
# 8            4.368948
# 9            4.735788
# 10           4.545104
# 11           5.331680
# 12           9.909655
# 13          53.296777

# %%
# what are some big names who can't be assigned to a particular region?

big_names = name_to_num_regions_of_origin.query('numRegionsOfOrigin > 1')
big_names['Rank'] = big_names.groupby('titleType')['TotalNumVotes'].rank(method='dense', ascending=False)
big_names = big_names.query('Rank <= 10')

big_names.sort_values(by=['titleType', 'Rank'])
# Out:
#        titleType             primaryName  numRegionsOfOrigin  TotalNumVotes  \
# 125266     movie       Christopher Nolan                   7      790761461
# 152817     movie           David Fincher                   7      442664432
# 119614     movie         Chris Hemsworth                   6      438654798
# 653019     movie              Tom Cruise                   5      425783725
# 624106     movie        Steven Spielberg                   4      406357624
# 553746     movie            Ridley Scott                   6      371050212
# 386152     movie       Leonardo DiCaprio                   3      369096153
# 72753      movie             Ben Affleck                   5      357921835
# 596142     movie              Seth Rogen                   6      347334312
# 674462     movie              Vin Diesel                   6      343233660
# 706472  tvSeries              Aaron Paul                   7      171502989
# 712422  tvSeries             Alfie Allen                   7      112741846
# 807894  tvSeries           Kit Harington                   7      112055846
# 876378  tvSeries           Sophie Turner                   7      111865971
# 759223  tvSeries           Emilia Clarke                   7      111701331
# 878708  tvSeries  Steven Michael Quezada                   7      104386170
# 842641  tvSeries   Nikolaj Coster-Waldau                   6       96011586
# 727426  tvSeries            Betsy Brandt                   6       90739716
# 849370  tvSeries            Pedro Pascal                   7       78269758
# 870771  tvSeries            Seth Gilliam                   7       72583651
#
#         Rank
# 125266   1.0
# 152817   2.0
# 119614   3.0
# 653019   4.0
# 624106   5.0
# 553746   6.0
# 386152   7.0
# 72753    8.0
# 596142   9.0
# 674462  10.0
# 706472   1.0
# 712422   2.0
# 807894   3.0
# 876378   4.0
# 759223   5.0
# 878708   6.0
# 842641   7.0
# 727426   8.0
# 849370   9.0
# 870771  10.0

# %%
# okay. So these are extremely popular artists whose movies pretty much
# always get released in more than 1 region

# %%
# well, our original problem is to assign titles to region of origin
# and not names to region of origin. May be we keep soft labels at name level
# and then see if we have enough discrimatory power at title level 
# when we aggregate them by names associated with the title

# %%
name_to_region_of_origin_soft_labels = title_to_names\
    .merge(title_basics[['tconst', 'titleType']], on='tconst')\
    .merge(ratings[['tconst', 'numVotes']], on='tconst', how='inner')\
    .merge(title_regions.query('language == "ALL"')[['tconst', 'region']], on='tconst', how='inner')\
    .groupby(['titleType', 'primaryName', 'category', 'region'])\
    .agg({'numVotes': 'sum', 'tconst': 'count'})\
    .reset_index()\
    .rename(columns={'tconst': 'numTitles'})\
    .sort_values(by=['titleType', 'primaryName', 'category', 'numVotes'], ascending=False)

# %%
name_to_region_of_origin_soft_labels.query('primaryName == "Leonardo DiCaprio"')
# Out:
#         titleType        primaryName category     region  numVotes  numTitles
# 2595237  tvSeries  Leonardo DiCaprio    actor  Australia     16719          2
# 2595238  tvSeries  Leonardo DiCaprio    actor     Canada     16719          2
# 2595241  tvSeries  Leonardo DiCaprio    actor      Japan     16719          2
# 2595242  tvSeries  Leonardo DiCaprio    actor         UK     16719          2
# 2595243  tvSeries  Leonardo DiCaprio    actor         US     16719          2
# 2595239  tvSeries  Leonardo DiCaprio    actor     France     16323          1
# 2595240  tvSeries  Leonardo DiCaprio    actor      India     16323          1
# 1253469     movie  Leonardo DiCaprio    actor     Canada  17585811         33
# 1253473     movie  Leonardo DiCaprio    actor         UK  17585811         33
# 1253474     movie  Leonardo DiCaprio    actor         US  17585811         33
# 1253472     movie  Leonardo DiCaprio    actor      Japan  17584135         32
# 1253468     movie  Leonardo DiCaprio    actor  Australia  17581296         32
# 1253470     movie  Leonardo DiCaprio    actor     France  17576547         31
# 1253471     movie  Leonardo DiCaprio    actor      India  17532640         29

# %%
name_to_region_of_origin_soft_labels.query('primaryName == "Aamir Khan"')
# Out:
#      titleType primaryName  category     region  numVotes  numTitles
# 2573     movie  Aamir Khan  director  Australia    206478          1
# 2574     movie  Aamir Khan  director     Canada    206478          1
# 2575     movie  Aamir Khan  director     France    206478          1
# 2576     movie  Aamir Khan  director      India    206478          1
# 2577     movie  Aamir Khan  director      Japan    206478          1
# 2578     movie  Aamir Khan  director         UK    206478          1
# 2579     movie  Aamir Khan  director         US    206478          1
# 2569     movie  Aamir Khan     actor      India   2089899         50
# 2572     movie  Aamir Khan     actor         US   2088929         49
# 2571     movie  Aamir Khan     actor         UK   2054418         35
# 2567     movie  Aamir Khan     actor     Canada   1972449         28
# 2566     movie  Aamir Khan     actor  Australia   1896881         20
# 2570     movie  Aamir Khan     actor      Japan   1763621         17
# 2568     movie  Aamir Khan     actor     France   1586338         11

# %%
title_to_region_of_origin_soft_labels = title_to_names\
    .merge(title_basics[['tconst', 'titleType']], on='tconst')\
    .merge(name_to_region_of_origin_soft_labels, on=['titleType', 'primaryName', 'category'], how='inner')\
    .groupby(['titleType', 'tconst', 'region'])\
    .agg({'numVotes': 'sum'})\
    .reset_index()\
    .merge(title_basics[['tconst', 'primaryTitle', 'startYear', 'genres']], on='tconst')\
    .sort_values(by=['titleType', 'tconst', 'numVotes'], ascending=False)

# %%
title_to_region_of_origin_soft_labels.query('primaryTitle == "3 Idiots"')
# Out:
#         titleType     tconst     region  numVotes primaryTitle startYear  \
# 1172207     movie  tt3685624         US   1250078     3 Idiots      2017
# 1172206     movie  tt3685624         UK   1239491     3 Idiots      2017
# 1172202     movie  tt3685624     Canada   1225339     3 Idiots      2017
# 1172201     movie  tt3685624  Australia   1219611     3 Idiots      2017
# 1172204     movie  tt3685624      India   1210170     3 Idiots      2017
# 1172203     movie  tt3685624     France   1059099     3 Idiots      2017
# 1172205     movie  tt3685624      Japan   1057484     3 Idiots      2017
# 776279      movie  tt1187043      India  10544508     3 Idiots      2009
# 776281      movie  tt1187043         UK  10361197     3 Idiots      2009
# 776282      movie  tt1187043         US  10300775     3 Idiots      2009
# 776277      movie  tt1187043     Canada   9909040     3 Idiots      2009
# 776276      movie  tt1187043  Australia   9674772     3 Idiots      2009
# 776280      movie  tt1187043      Japan   8482802     3 Idiots      2009
# 776278      movie  tt1187043     France   8322505     3 Idiots      2009
#
#                genres
# 1172207        Comedy
# 1172206        Comedy
# 1172202        Comedy
# 1172201        Comedy
# 1172204        Comedy
# 1172203        Comedy
# 1172205        Comedy
# 776279   Comedy,Drama
# 776281   Comedy,Drama
# 776282   Comedy,Drama
# 776277   Comedy,Drama
# 776276   Comedy,Drama
# 776280   Comedy,Drama
# 776278   Comedy,Drama

# %%
title_to_region_of_origin_soft_labels.query('primaryTitle == "Inception"')
# Out:
#        titleType     tconst     region  numVotes primaryTitle startYear  \
# 836440     movie  tt1375666         US  92177919    Inception      2010
# 836439     movie  tt1375666         UK  92176116    Inception      2010
# 836435     movie  tt1375666     Canada  92132678    Inception      2010
# 836438     movie  tt1375666      Japan  92066306    Inception      2010
# 836434     movie  tt1375666  Australia  92026924    Inception      2010
# 836436     movie  tt1375666     France  91986868    Inception      2010
# 836437     movie  tt1375666      India  91209580    Inception      2010
#
#                          genres
# 836440  Action,Adventure,Sci-Fi
# 836439  Action,Adventure,Sci-Fi
# 836435  Action,Adventure,Sci-Fi
# 836438  Action,Adventure,Sci-Fi
# 836434  Action,Adventure,Sci-Fi
# 836436  Action,Adventure,Sci-Fi
# 836437  Action,Adventure,Sci-Fi

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt4154756"')
# Out:
#         titleType     tconst     region   numVotes            primaryTitle  \
# 1198042     movie  tt4154756         US  108321403  Avengers: Infinity War
# 1198041     movie  tt4154756         UK  108319498  Avengers: Infinity War
# 1198037     movie  tt4154756     Canada  108299919  Avengers: Infinity War
# 1198036     movie  tt4154756  Australia  108294133  Avengers: Infinity War
# 1198040     movie  tt4154756      Japan  108239333  Avengers: Infinity War
# 1198038     movie  tt4154756     France  108191549  Avengers: Infinity War
# 1198039     movie  tt4154756      India  107085333  Avengers: Infinity War
#
#         startYear                   genres
# 1198042      2018  Action,Adventure,Sci-Fi
# 1198041      2018  Action,Adventure,Sci-Fi
# 1198037      2018  Action,Adventure,Sci-Fi
# 1198036      2018  Action,Adventure,Sci-Fi
# 1198040      2018  Action,Adventure,Sci-Fi
# 1198038      2018  Action,Adventure,Sci-Fi
# 1198039      2018  Action,Adventure,Sci-Fi

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt0112870"')
# Out:
#        titleType     tconst     region  numVotes                 primaryTitle  \
# 348037     movie  tt0112870      India   8481913  Dilwale Dulhania Le Jayenge
# 348040     movie  tt0112870         US   8120542  Dilwale Dulhania Le Jayenge
# 348039     movie  tt0112870         UK   8054169  Dilwale Dulhania Le Jayenge
# 348035     movie  tt0112870     Canada   7622454  Dilwale Dulhania Le Jayenge
# 348034     movie  tt0112870  Australia   7027477  Dilwale Dulhania Le Jayenge
# 348038     movie  tt0112870      Japan   6187528  Dilwale Dulhania Le Jayenge
# 348036     movie  tt0112870     France   5958008  Dilwale Dulhania Le Jayenge
#
#        startYear         genres
# 348037      1995  Drama,Romance
# 348040      1995  Drama,Romance
# 348039      1995  Drama,Romance
# 348035      1995  Drama,Romance
# 348034      1995  Drama,Romance
# 348038      1995  Drama,Romance
# 348036      1995  Drama,Romance

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt6470478"')
# Out:
#         titleType     tconst     region  numVotes     primaryTitle startYear  \
# 1671089  tvSeries  tt6470478         US   1982446  The Good Doctor      2017
# 1671084  tvSeries  tt6470478     Canada   1980742  The Good Doctor      2017
# 1671083  tvSeries  tt6470478  Australia   1979389  The Good Doctor      2017
# 1671088  tvSeries  tt6470478         UK   1977032  The Good Doctor      2017
# 1671087  tvSeries  tt6470478      Japan   1972324  The Good Doctor      2017
# 1671086  tvSeries  tt6470478      India   1962196  The Good Doctor      2017
# 1671085  tvSeries  tt6470478     France   1961234  The Good Doctor      2017
#
#         genres
# 1671089  Drama
# 1671084  Drama
# 1671083  Drama
# 1671088  Drama
# 1671087  Drama
# 1671086  Drama
# 1671085  Drama

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt0988824"')
# Out:
#         titleType     tconst     region  numVotes       primaryTitle  \
# 1500914  tvSeries  tt0988824         US   3550555  Naruto: Shippuden
# 1500912  tvSeries  tt0988824      Japan   3538257  Naruto: Shippuden
# 1500909  tvSeries  tt0988824     Canada   3505570  Naruto: Shippuden
# 1500913  tvSeries  tt0988824         UK   3488499  Naruto: Shippuden
# 1500911  tvSeries  tt0988824      India   3486013  Naruto: Shippuden
# 1500908  tvSeries  tt0988824  Australia   3444041  Naruto: Shippuden
# 1500910  tvSeries  tt0988824     France   3435617  Naruto: Shippuden
#
#         startYear                      genres
# 1500914      2007  Action,Adventure,Animation
# 1500912      2007  Action,Adventure,Animation
# 1500909      2007  Action,Adventure,Animation
# 1500913      2007  Action,Adventure,Animation
# 1500911      2007  Action,Adventure,Animation
# 1500908      2007  Action,Adventure,Animation
# 1500910      2007  Action,Adventure,Animation

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt2098220"')
# Out:
#         titleType     tconst     region  numVotes     primaryTitle startYear  \
# 1586032  tvSeries  tt2098220      Japan   2398355  Hunter x Hunter      2011
# 1586034  tvSeries  tt2098220         US   2375216  Hunter x Hunter      2011
# 1586031  tvSeries  tt2098220      India   2348794  Hunter x Hunter      2011
# 1586033  tvSeries  tt2098220         UK   2334319  Hunter x Hunter      2011
# 1586029  tvSeries  tt2098220     Canada   2333899  Hunter x Hunter      2011
# 1586028  tvSeries  tt2098220  Australia   2257774  Hunter x Hunter      2011
# 1586030  tvSeries  tt2098220     France   2221810  Hunter x Hunter      2011
#
#                              genres
# 1586032  Action,Adventure,Animation
# 1586034  Action,Adventure,Animation
# 1586031  Action,Adventure,Animation
# 1586033  Action,Adventure,Animation
# 1586029  Action,Adventure,Animation
# 1586028  Action,Adventure,Animation
# 1586030  Action,Adventure,Animation

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt2560140"')
# Out:
#         titleType     tconst     region  numVotes     primaryTitle startYear  \
# 1606451  tvSeries  tt2560140      Japan   6411019  Attack on Titan      2013
# 1606453  tvSeries  tt2560140         US   6385352  Attack on Titan      2013
# 1606450  tvSeries  tt2560140      India   6355637  Attack on Titan      2013
# 1606452  tvSeries  tt2560140         UK   6330105  Attack on Titan      2013
# 1606448  tvSeries  tt2560140     Canada   6318066  Attack on Titan      2013
# 1606449  tvSeries  tt2560140     France   6216899  Attack on Titan      2013
# 1606447  tvSeries  tt2560140  Australia   6187606  Attack on Titan      2013
#
#                              genres
# 1606451  Action,Adventure,Animation
# 1606453  Action,Adventure,Animation
# 1606450  Action,Adventure,Animation
# 1606452  Action,Adventure,Animation
# 1606448  Action,Adventure,Animation
# 1606449  Action,Adventure,Animation
# 1606447  Action,Adventure,Animation

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt0386676"') # the office US
# Out:
#         titleType     tconst     region  numVotes primaryTitle startYear  \
# 1478234  tvSeries  tt0386676         US   7542002   The Office      2005
# 1478229  tvSeries  tt0386676     Canada   7539751   The Office      2005
# 1478228  tvSeries  tt0386676  Australia   7537647   The Office      2005
# 1478233  tvSeries  tt0386676         UK   7533215   The Office      2005
# 1478231  tvSeries  tt0386676      India   7531986   The Office      2005
# 1478230  tvSeries  tt0386676     France   7518991   The Office      2005
# 1478232  tvSeries  tt0386676      Japan   7512407   The Office      2005
#
#          genres
# 1478234  Comedy
# 1478229  Comedy
# 1478228  Comedy
# 1478233  Comedy
# 1478231  Comedy
# 1478230  Comedy
# 1478232  Comedy

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt0290978"') # the office UK
# Out:
#         titleType     tconst     region  numVotes primaryTitle startYear  \
# 1466177  tvSeries  tt0290978         UK   3202907   The Office      2001
# 1466178  tvSeries  tt0290978         US   3200675   The Office      2001
# 1466173  tvSeries  tt0290978     Canada   3199899   The Office      2001
# 1466172  tvSeries  tt0290978  Australia   3199306   The Office      2001
# 1466176  tvSeries  tt0290978      Japan   3194956   The Office      2001
# 1466174  tvSeries  tt0290978     France   3191432   The Office      2001
# 1466175  tvSeries  tt0290978      India   3189278   The Office      2001
#
#                genres
# 1466177  Comedy,Drama
# 1466178  Comedy,Drama
# 1466173  Comedy,Drama
# 1466172  Comedy,Drama
# 1466176  Comedy,Drama
# 1466174  Comedy,Drama
# 1466175  Comedy,Drama

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt0290988"')
# Out:
#         titleType     tconst     region  numVotes       primaryTitle  \
# 1466212  tvSeries  tt0290988     Canada    589542  Trailer Park Boys
# 1466217  tvSeries  tt0290988         US    589286  Trailer Park Boys
# 1466211  tvSeries  tt0290988  Australia    585180  Trailer Park Boys
# 1466213  tvSeries  tt0290988     France    584512  Trailer Park Boys
# 1466215  tvSeries  tt0290988      Japan    576850  Trailer Park Boys
# 1466216  tvSeries  tt0290988         UK    576850  Trailer Park Boys
# 1466214  tvSeries  tt0290988      India    546409  Trailer Park Boys
#
#         startYear        genres
# 1466212      2001  Comedy,Crime
# 1466217      2001  Comedy,Crime
# 1466211      2001  Comedy,Crime
# 1466213      2001  Comedy,Crime
# 1466215      2001  Comedy,Crime
# 1466216      2001  Comedy,Crime
# 1466214      2001  Comedy,Crime

# %%
title_to_region_of_origin_soft_labels.query('tconst == "tt5687612"')
# Out:
#         titleType     tconst     region  numVotes primaryTitle startYear  \
# 1660610  tvSeries  tt5687612         UK   3887578      Fleabag      2016
# 1660611  tvSeries  tt5687612         US   3883937      Fleabag      2016
# 1660606  tvSeries  tt5687612     Canada   3883467      Fleabag      2016
# 1660605  tvSeries  tt5687612  Australia   3882265      Fleabag      2016
# 1660609  tvSeries  tt5687612      Japan   3863674      Fleabag      2016
# 1660608  tvSeries  tt5687612      India   3826713      Fleabag      2016
# 1660607  tvSeries  tt5687612     France   3798608      Fleabag      2016
#
#                genres
# 1660610  Comedy,Drama
# 1660611  Comedy,Drama
# 1660606  Comedy,Drama
# 1660605  Comedy,Drama
# 1660609  Comedy,Drama
# 1660608  Comedy,Drama
# 1660607  Comedy,Drama

# %%
# okay! This seems to be working well! What fraction of titles are still inconclusive at this point?

title_to_region_of_origin_hard_labels = title_to_region_of_origin_soft_labels.copy()

title_to_region_of_origin_hard_labels['RegionRankPerTitle'] = \
    title_to_region_of_origin_hard_labels.groupby(['titleType', 'tconst'])['numVotes'].rank(method='dense', ascending=False)

title_to_region_of_origin_hard_labels = title_to_region_of_origin_hard_labels.query('RegionRankPerTitle == 1')

# %%
title_to_region_of_origin_hard_labels.query('tconst == "tt5687612"')
# Out:
#         titleType     tconst region  numVotes primaryTitle startYear  \
# 1660610  tvSeries  tt5687612     UK   3887578      Fleabag      2016
#
#                genres  RegionRankPerTitle
# 1660610  Comedy,Drama                 1.0

# %%
title_to_num_regions_of_origin = title_to_region_of_origin_hard_labels\
    .groupby(['titleType', 'tconst', 'primaryTitle', 'startYear', 'genres'])\
    .agg({'region': 'count'})\
    .reset_index()\
    .rename(columns={'region': 'numRegionsOfOrigin'})\
    .merge(ratings[['tconst', 'numVotes']], on='tconst')

stats = title_to_num_regions_of_origin\
    .groupby(['titleType', 'numRegionsOfOrigin'])\
    .agg({'tconst': 'count', 'numVotes': 'sum'})\
    .reset_index()\
    .rename(columns={'tconst': 'numTitles'})

stats['PercentageByCount'] = 100 * stats['numTitles'] / stats.groupby('titleType')['numTitles'].transform('sum')
stats['PercentageByVotes'] = 100 * stats['numVotes'] / stats.groupby('titleType')['numVotes'].transform('sum')

stats
# Out:
#    titleType  numRegionsOfOrigin  numTitles    numVotes  PercentageByCount  \
# 0      movie                   1     218257  1102053655          94.998847
# 1      movie                   2       8465     5144102           3.684488
# 2      movie                   3       1746     1571727           0.759966
# 3      movie                   4        701      632734           0.305118
# 4      movie                   5        325      564412           0.141460
# 5      movie                   6        149      371522           0.064854
# 6      movie                   7        104      684355           0.045267
# 7   tvSeries                   1      49790   136955635          95.503894
# 8   tvSeries                   2       1459     1278344           2.798558
# 9   tvSeries                   3        434      245275           0.832470
# 10  tvSeries                   4        173       76446           0.331837
# 11  tvSeries                   5        108      169427           0.207158
# 12  tvSeries                   6         69      181068           0.132351
# 13  tvSeries                   7        101      369546           0.193732
#
#     PercentageByVotes
# 0           99.192739
# 1            0.463006
# 2            0.141467
# 3            0.056951
# 4            0.050801
# 5            0.033440
# 6            0.061597
# 7           98.334164
# 8            0.917851
# 9            0.176107
# 10           0.054888
# 11           0.121649
# 12           0.130007
# 13           0.265334

# %%
# Nice! Almost all movies and shows are assigned a unique region of origin
# now top titles per region of origin should vary across regions. Lets
# see if thats the case

# %%
region_of_origin_per_title = title_to_region_of_origin_hard_labels\
    [['tconst', 'region']]\
    .rename(columns = {'region': 'RegionOfOrigin'})

top_titles_per_region = title_basics\
    .merge(region_of_origin_per_title, on='tconst')\
    .merge(ratings, on='tconst')
    
top_titles_per_region['Rank'] = top_titles_per_region\
    .groupby(['RegionOfOrigin', 'titleType'])['numVotes']\
    .rank(method='dense', ascending=False)

top_titles_per_region = top_titles_per_region.query('Rank <= 20')

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(top_titles_per_region.sort_values(by=['RegionOfOrigin', 'titleType', 'Rank']))
# Out:
#             tconst titleType  \
# 200155   tt2119532     movie
# 209995   tt2321549     movie
# 154871  tt13345606     movie
# 111770   tt0455824     movie
# 138462  tt11464826     movie
# 168688  tt14992922     movie
# 200641   tt2125608     movie
# 176387   tt1587707     movie
# 118667   tt0815241     movie
# 273482   tt6333060     movie
# 152544   tt1313104     movie
# 193380   tt1966604     movie
# 217795   tt2592910     movie
# 152958   tt1316536     movie
# 78840    tt0221073     movie
# 50593    tt0103767     movie
# 285923   tt7664504     movie
# 287885   tt7905466     movie
# 122132   tt0923752     movie
# 247373   tt4068576     movie
# 282909   tt7335184  tvSeries
# 178426   tt1628033  tvSeries
# 252919   tt4532368  tvSeries
# 264912   tt5607976  tvSeries
# 130531  tt10638036  tvSeries
# 250279   tt4299972  tvSeries
# 291092   tt8289930  tvSeries
# 264500   tt5574490  tvSeries
# 276677   tt6656238  tvSeries
# 183332   tt1728102  tvSeries
# 72401    tt0187636  tvSeries
# 294828   tt8778064  tvSeries
# 284066   tt7472896  tvSeries
# 141816  tt11847842  tvSeries
# 33744    tt0071075  tvSeries
# 272034   tt6205862  tvSeries
# 286032   tt7678620  tvSeries
# 293707   tt8633062  tvSeries
# 214655   tt2433738  tvSeries
# 251163   tt4374208  tvSeries
# 59655    tt0123755     movie
# 142026  tt11866324     movie
# 147525   tt1255953     movie
# 138463  tt11464826     movie
# 179501   tt1645089     movie
# 168689  tt14992922     movie
# 200642   tt2125608     movie
# 176388   tt1587707     movie
# 241308   tt3612616     movie
# 118668   tt0815241     movie
# 185362   tt1772240     movie
# 285961   tt7668842     movie
# 150119   tt1286537     movie
# 193381   tt1966604     movie
# 120154   tt0848557     movie
# 217796   tt2592910     movie
# 102855   tt0377713     movie
# 41260    tt0085809     movie
# 148456  tt12676326     movie
# 50594    tt0103767     movie
# 214779   tt2442560  tvSeries
# 142409   tt1190634  tvSeries
# 106750   tt0411008  tvSeries
# 209379   tt2306299  tvSeries
# 260342   tt5180504  tvSeries
# 206486   tt2243973  tvSeries
# 152448   tt1312171  tvSeries
# 267599   tt5834204  tvSeries
# 51789    tt0106179  tvSeries
# 103809   tt0384766  tvSeries
# 235536   tt3230854  tvSeries
# 239964   tt3526078  tvSeries
# 206115   tt2234222  tvSeries
# 296218   tt8962124  tvSeries
# 202103   tt2149175  tvSeries
# 260972   tt5232792  tvSeries
# 57536    tt0118480  tvSeries
# 132027  tt10795658  tvSeries
# 165651   tt1462059  tvSeries
# 292173   tt8421350  tvSeries
# 180910   tt1675434     movie
# 77165    tt0211915     movie
# 103386   tt0381681     movie
# 46438    tt0095765     movie
# 2758     tt0017136     movie
# 136703   tt1129442     movie
# 208190   tt2278871     movie
# 90646    tt0290673     movie
# 23016    tt0053198     movie
# 182037  tt17009710     movie
# 105762   tt0401383     movie
# 54335    tt0111495     movie
# 177102   tt1602620     movie
# 145822   tt1235166     movie
# 118278   tt0808417     movie
# 101081   tt0364970     movie
# 111060   tt0450188     movie
# 49562    tt0101700     movie
# 64860    tt0152930     movie
# 257644   tt4954522     movie
# 266606   tt5753856  tvSeries
# 216582   tt2531336  tvSeries
# 130533  tt10638036  tvSeries
# 134266   tt1103987  tvSeries
# 250281   tt4299972  tvSeries
# 291094   tt8289930  tvSeries
# 133114  tt10919486  tvSeries
# 247188   tt4057372  tvSeries
# 33746    tt0071075  tvSeries
# 272036   tt6205862  tvSeries
# 216396   tt2521668  tvSeries
# 151870  tt13062500  tvSeries
# 238644   tt3444938  tvSeries
# 184095  tt17444636  tvSeries
# 132702  tt10875696  tvSeries
# 134580  tt11070216  tvSeries
# 168155   tt1492088  tvSeries
# 95287    tt0320037  tvSeries
# 250021   tt4277922  tvSeries
# 247298   tt4063800  tvSeries
# 125208   tt1010048     movie
# 132169  tt10811166     movie
# 142071   tt1187043     movie
# 296010   tt8936646     movie
# 169618  tt15097216     movie
# 258968   tt5074352     movie
# 123853   tt0986264     movie
# 210605   tt2338151     movie
# 132841  tt10888594     movie
# 124573  tt10028196     movie
# 290241   tt8178634     movie
# 149927  tt12844910     movie
# 131176  tt10698680     movie
# 218630   tt2631186     movie
# 289735   tt8110330     movie
# 150562  tt12915716     movie
# 127117  tt10295212     movie
# 126089  tt10189514     movie
# 106193   tt0405508     movie
# 68884    tt0169102     movie
# 163496  tt14392248  tvSeries
# 165889  tt14650074  tvSeries
# 300322   tt9544034  tvSeries
# 270402   tt6077448  tvSeries
# 143172  tt12004706  tvSeries
# 275043   tt6473300  tvSeries
# 299749   tt9432978  tvSeries
# 225337  tt28227737  tvSeries
# 255329   tt4742876  tvSeries
# 142476  tt11912196  tvSeries
# 301272   tt9680440  tvSeries
# 230913  tt30263074  tvSeries
# 134977  tt11117570  tvSeries
# 193772  tt19768024  tvSeries
# 149573  tt12805346  tvSeries
# 290735   tt8242548  tvSeries
# 225191  tt28184392  tvSeries
# 250282   tt4299972  tvSeries
# 291095   tt8289930  tvSeries
# 204690  tt22014226  tvSeries
# 98327    tt0347149     movie
# 46703    tt0096283     movie
# 19608    tt0047478     movie
# 261876   tt5311514     movie
# 46217    tt0095327     movie
# 45818    tt0094625     movie
# 86300    tt0266308     movie
# 42140    tt0087544     movie
# 44431    tt0092067     movie
# 16871    tt0042876     movie
# 154993   tt1335975     movie
# 116281   tt0498380     movie
# 55287    tt0113568     movie
# 43308    tt0089881     movie
# 24546    tt0055630     movie
# 290922   tt8267604     movie
# 51017    tt0104652     movie
# 262009   tt5323662     movie
# 195460   tt2013293     movie
# 120218   tt0851578     movie
# 133112  tt10919420  tvSeries
# 274989   tt6468322  tvSeries
# 217180   tt2560140  tvSeries
# 59192    tt0121955  tvSeries
# 104309   tt0388629  tvSeries
# 157081   tt1355642  tvSeries
# 252621   tt4508902  tvSeries
# 140796  tt11737520  tvSeries
# 299152   tt9335498  tvSeries
# 77395    tt0213338  tvSeries
# 198880   tt2098220  tvSeries
# 220007  tt26693803  tvSeries
# 145744  tt12343534  tvSeries
# 59028    tt0121220  tvSeries
# 54650    tt0112159  tvSeries
# 124071   tt0994314  tvSeries
# 265145   tt5626028  tvSeries
# 107943   tt0421357  tvSeries
# 130534  tt10638036  tvSeries
# 191380   tt1910272  tvSeries
# 58818    tt0120737     movie
# 68385    tt0167260     movie
# 68386    tt0167261     movie
# 102196   tt0372784     movie
# 36740    tt0076759     movie
# 114772   tt0482571     movie
# 96058    tt0325980     movie
# 109388   tt0434409     movie
# 215771   tt2488496     movie
# 241913   tt3659388     movie
# 84044    tt0253474     movie
# 76489    tt0208092     movie
# 112086   tt0458339     movie
# 121717   tt0903624     movie
# 145262   tt1228705     movie
# 107285   tt0416449     movie
# 187637   tt1825683     movie
# 198204   tt2084970     movie
# 94790    tt0317705     movie
# 143973   tt1211837     movie
# 122664   tt0944947  tvSeries
# 166781   tt1475582  tvSeries
# 198213   tt2085059  tvSeries
# 135819  tt11198330  tvSeries
# 285614   tt7631058  tvSeries
# 286824   tt7767422  tvSeries
# 133851  tt10986410  tvSeries
# 255722   tt4786824  tvSeries
# 109686   tt0436992  tvSeries
# 243357   tt3749900  tvSeries
# 177311   tt1606375  tvSeries
# 272645   tt6257970  tvSeries
# 265895   tt5687612  tvSeries
# 188677   tt1839578  tvSeries
# 230440   tt3006802  tvSeries
# 248906   tt4179452  tvSeries
# 298658   tt9253284  tvSeries
# 115267   tt0487831  tvSeries
# 166681   tt1474684  tvSeries
# 291989   tt8398600  tvSeries
# 54185    tt0111161     movie
# 113170   tt0468569     movie
# 157769   tt1375666     movie
# 62326    tt0137523     movie
# 53563    tt0109830     movie
# 54060    tt0110912     movie
# 118779   tt0816692     movie
# 61459    tt0133093     movie
# 267599             60        Drama,Sci-Fi,Thriller         Canada
# 51789              45          Crime,Drama,Mystery         Canada
# 103809             60         Action,Drama,Romance         Canada
# 235536             60         Drama,Mystery,Sci-Fi         Canada
# 239964             22                       Comedy         Canada
# 206115             44        Drama,Sci-Fi,Thriller         Canada
# 296218             30         Comedy,Drama,Romance         Canada
# 202103             44          Crime,Drama,Mystery         Canada
# 260972             60       Adventure,Drama,Family         Canada
# 57536              44       Action,Adventure,Drama         Canada
# 132027             50         Action,Drama,Mystery         Canada
# 165651             42       Action,Adventure,Drama         Canada
# 292173             43         Drama,Mystery,Sci-Fi         Canada
# 180910            112                 Comedy,Drama         France
# 77165             122               Comedy,Romance         France
# 103386             80                Drama,Romance         France
# 46438             174                Drama,Romance         France
# 2758              153                 Drama,Sci-Fi         France
# 136703            104    Action,Adventure,Thriller         France
# 208190            180                Drama,Romance         France
# 90646              97          Crime,Drama,Mystery         France
# 23016              99                  Crime,Drama         France
# 182037            151         Crime,Drama,Thriller         France
# 105762            112              Biography,Drama         France
# 54335              99        Drama,Mystery,Romance         France
# 177102            127                        Drama         France
# 145822            155                  Crime,Drama         France
# 118278             96    Animation,Biography,Drama         France
# 101081             90      Action,Adventure,Sci-Fi         France
# 111060            140        Biography,Drama,Music         France
# 49562              99                 Comedy,Crime         France
# 64860              89          Action,Comedy,Crime         France
# 257644             99                 Drama,Horror         France
# 266606             60          Crime,Drama,Mystery         France
# 216582             45           Action,Crime,Drama         France
# 130533             30                Drama,Romance         France
# 134266             42       Crime,Mystery,Thriller         France
# 250281             45  Biography,Crime,Documentary         France
# 291094             40            Documentary,Sport         France
# 133114             35        Drama,Sci-Fi,Thriller         France
# 247188             \N      Animation,Comedy,Family         France
# 33746              50      Documentary,History,War         France
# 272036              5            Documentary,Short         France
# 216396             \N         Drama,Fantasy,Horror         France
# 151870             60                 Drama,Horror         France
# 238644             60       Comedy,Music,Talk-Show         France
# 184095             21         Comedy,Drama,Romance         France
# 132702             50         Drama,Horror,Mystery         France
# 134580             \N             Animation,Comedy         France
# 168155             30            Comedy,Reality-TV         France
# 95287              60       Comedy,Music,Talk-Show         France
# 250021             52                 Comedy,Drama         France
# 247298             50               Drama,Thriller         France
# 125208            120          Crime,Drama,Romance          India
# 132169            170                        Drama          India
# 142071            170                 Comedy,Drama          India
# 296010            116              Action,Thriller          India
# 169618            164          Crime,Drama,Mystery          India
# 258968            161       Action,Biography,Drama          India
# 123853            162                 Drama,Family          India
# 210605            153          Comedy,Drama,Sci-Fi          India
# 132841            109        Action,Crime,Thriller          India
# 124573            159         Comedy,Drama,Romance          India
# 290241            187       Action,Adventure,Drama          India
# 149927            146    Action,Adventure,Thriller          India
# 131176            166           Action,Crime,Drama          India
# 218630            159                 Action,Drama          India
# 289735            101         Comedy,Drama,Romance          India
# 150562            179       Action,Adventure,Drama          India
# 127117            135       Action,Biography,Drama          India
# 126089            153                 Action,Drama          India
# 106193            167           Comedy,Crime,Drama          India
# 68884             224          Drama,Musical,Sport          India
# 163496             45                        Drama          India
# 165889             25                 Comedy,Drama          India
# 300322             45          Action,Comedy,Drama          India
# 270402             50           Action,Crime,Drama          India
# 143172             30                 Comedy,Drama          India
# 275043             60           Action,Crime,Drama          India
# 299749             40                 Comedy,Drama          India
# 225337             \N                        Drama          India
# 255329             40                 Comedy,Drama          India
# 142476             43          Crime,Drama,Mystery          India
# 301272             44         Crime,Drama,Thriller          India
# 230913             \N                        Drama          India
# 134977             30               Drama,Thriller          India
# 193772             \N                 Action,Crime          India
# 149573             45          Crime,Drama,Mystery          India
# 290735             60         Comedy,Drama,Romance          India
# 225191             55          Crime,Drama,Musical          India
# 250282             45  Biography,Crime,Documentary          India
# 291095             40            Documentary,Sport          India
# 204690             29          Action,Comedy,Drama          India
# 98327             119   Adventure,Animation,Family          Japan
# 46703              86      Animation,Comedy,Family          Japan
# 19608             207                 Action,Drama          Japan
# 261876            106      Animation,Drama,Fantasy          Japan
# 46217              89          Animation,Drama,War          Japan
# 45818             124       Action,Animation,Drama          Japan
# 86300             114       Action,Adventure,Drama          Japan
# 42140             117   Adventure,Animation,Sci-Fi          Japan
# 44431             125   Adventure,Animation,Family          Japan
# 16871              88          Crime,Drama,Mystery          Japan
# 154993            128         Action,Drama,Fantasy          Japan
# 116281            141       Action,Adventure,Drama          Japan
# 55287              83       Action,Animation,Crime          Japan
# 43308             160             Action,Drama,War          Japan
# 24546             110        Action,Drama,Thriller          Japan
# 290922            126                        Drama          Japan
# 51017              94   Adventure,Animation,Comedy          Japan
# 262009            130              Animation,Drama          Japan
# 195460            126    Animation,Biography,Drama          Japan
# 120218             90      Animation,Drama,Fantasy          Japan
# 133112             60         Action,Drama,Mystery          Japan
# 274989             60           Action,Crime,Drama          Japan
# 217180             24   Action,Adventure,Animation          Japan
# 59192              22             Animation,Comedy          Japan
# 104309             24   Action,Adventure,Animation          Japan
# 157081             24   Action,Adventure,Animation          Japan
# 252621             24      Action,Animation,Comedy          Japan
# 140796             60      Action,Adventure,Comedy          Japan
# 299152             24   Action,Adventure,Animation          Japan
# 77395              24   Action,Adventure,Animation          Japan
# 198880             24   Action,Adventure,Animation          Japan
# 220007             60         Comedy,Drama,Romance          Japan
# 145744             24   Action,Adventure,Animation          Japan
# 59028              24   Action,Adventure,Animation          Japan
# 54650              24       Action,Animation,Drama          Japan
# 124071             24       Action,Animation,Drama          Japan
# 265145             24   Action,Adventure,Animation          Japan
# 107943             24   Action,Adventure,Animation          Japan
# 130534             30                Drama,Romance          Japan
# 191380             24       Animation,Comedy,Drama          Japan
# 58818             178       Action,Adventure,Drama             UK
# 68385             201       Action,Adventure,Drama             UK
# 68386             179       Action,Adventure,Drama             UK
# 102196            140           Action,Crime,Drama             UK
# 36740             121     Action,Adventure,Fantasy             UK
# 114772            130         Drama,Mystery,Sci-Fi             UK
# 96058             143     Action,Adventure,Fantasy             UK
# 109388            132          Action,Drama,Sci-Fi             UK
# 215771            138      Action,Adventure,Sci-Fi             UK
# 241913            144       Adventure,Drama,Sci-Fi             UK
# 84044             150        Biography,Drama,Music             UK
# 76489             102                 Comedy,Crime             UK
# 112086            124      Action,Adventure,Sci-Fi             UK
# 121717            169            Adventure,Fantasy             UK
# 145262            124                Action,Sci-Fi             UK
# 107285            117                 Action,Drama             UK
# 187637            134      Action,Adventure,Sci-Fi             UK
# 198204            114     Biography,Drama,Thriller             UK
# 94790             115   Action,Adventure,Animation             UK
# 143973            115     Action,Adventure,Fantasy             UK
# 122664             60       Action,Adventure,Drama             UK
# 166781             90          Crime,Drama,Mystery             UK
# 198213             60         Drama,Mystery,Sci-Fi             UK
# 135819             50       Action,Adventure,Drama             UK
# 285614             60       Action,Adventure,Drama             UK
# 286824             60         Comedy,Drama,Romance             UK
# 133851             30           Comedy,Drama,Sport             UK
# 255722             60      Biography,Drama,History             UK
# 109686             45       Adventure,Drama,Sci-Fi             UK
# 243357             42           Action,Crime,Drama             UK
# 177311             60                Drama,Romance             UK
# 272645             25       Adventure,Comedy,Crime             UK
# 265895             30                 Comedy,Drama             UK
# 188677             43           Action,Crime,Drama             UK
# 230440             60        Drama,Fantasy,Romance             UK
# 248906             60         Action,Drama,History             UK
# 298658             40       Action,Adventure,Drama             UK
# 115267             25                       Comedy             UK
# 166681             60          Crime,Drama,Mystery             UK
# 291989             30                 Comedy,Drama             UK
# 54185             142                        Drama             US
# 113170            152           Action,Crime,Drama             US
# 157769            148      Action,Adventure,Sci-Fi             US
# 62326             139                        Drama             US
# 53563             142                Drama,Romance             US
# 54060             154                  Crime,Drama             US
# 118779            169       Adventure,Drama,Sci-Fi             US
# 61459             136                Action,Sci-Fi             US
# 32359             175                  Crime,Drama             US
# 156255            164        Action,Drama,Thriller             US
# 55652             127          Crime,Drama,Mystery             US
# 189305            165                Drama,Western             US
# 69449             155       Action,Adventure,Drama             US
# 100509            153          Adventure,Drama,War             US
# 124064            180       Biography,Comedy,Crime             US
# 50146             118         Crime,Drama,Thriller             US
# 58874             169                    Drama,War             US
# 282430            122         Crime,Drama,Thriller             US
# 120138            143                Action,Sci-Fi             US
# 136833            138       Drama,Mystery,Thriller             US
# 121727             45         Crime,Drama,Thriller             US
# 253393             60         Drama,Fantasy,Horror             US
# 53019              22               Comedy,Romance             US
# 170616             45        Drama,Horror,Thriller             US
# 121584             22               Comedy,Romance             US
# 116953             60          Crime,Drama,Mystery             US
# 112307             \N         Comedy,Drama,Romance             US
# 104047             22                       Comedy             US
# 211262             60          Crime,Drama,Mystery             US
# 231115             45                  Crime,Drama             US
# 226667             23   Adventure,Animation,Comedy             US
# 289748             40     Action,Adventure,Fantasy             US
# 111701             44           Action,Crime,Drama             US
# 260343             60       Action,Adventure,Drama             US
# 113915             60         Drama,Mystery,Sci-Fi             US
# 189463             50                        Drama             US
# 240859             50       Action,Adventure,Drama             US
# 106854             45                Drama,Mystery             US
# 163848             22         Comedy,Drama,Romance             US
# 112329             44         Drama,Fantasy,Horror             US
#
#         averageRating  numVotes  Rank
# 200155            8.1    592820   1.0
# 209995            6.8    246902   2.0
# 154871            6.5    136089   3.0
